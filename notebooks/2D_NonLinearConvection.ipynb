# %% [markdown]
# ## Imports

# %%
import numpy as np
from matplotlib import pyplot, cm
from mpl_toolkits.mplot3d import Axes3D

import time
from numba import njit
from pyccel.epyccel import epyccel
from pyccel.decorators import types

# %% [markdown]
# ## Pure python function

# %%
def solve_2d_nonlinearconv_pure(u, un, v, vn, nt, dt, dx, dy, c):

    ###Assign initial conditions
    ##set hat function I.C. : u(.5<=x<=1 && .5<=y<=1 ) is 2
    u[int(.5 / dy):int(1 / dy + 1), int(.5 / dx):int(1 / dx + 1)] = 2
    ##set hat function I.C. : v(.5<=x<=1 && .5<=y<=1 ) is 2
    v[int(.5 / dy):int(1 / dy + 1), int(.5 / dx):int(1 / dx + 1)] = 2
    row, col = u.shape
    
    
    kx=dt/dx
    ky=dt/dy
    
    for k in range(nt):
        un=u.copy()
        vn=v.copy()
        for i in range(1, row-1):
            for j in range(1, col-1):
                                                          
                u[i,j]=(un[i,j] -
                        kx*un[i,j]*(un[i,j] - un[i-1,j]) -
                        ky*vn[i,j]*(un[i,j] - un[i,j-1]))
                
                u[i,j]=(vn[i,j] -
                        kx*un[i,j]*(vn[i,j] - vn[i-1,j]) -
                        ky*vn[i,j]*(vn[i,j] - vn[i,j-1]))
                
                                
        u[0, :] = 1
        u[:, 0] = 1
        u[row-1, :] = 1
        u[:, col-1] = 1
        
        v[0, :] = 1
        v[:, 0] = 1
        v[row-1, :] = 1
        v[:, col-1] = 1
        
        
    return 0

# %% [markdown]
# ## Numba accelerator

# %%
@njit(fastmath=True)
def solve_2d_nonlinearconv_numba(u, un, v, vn, nt, dt, dx, dy, c):

    ###Assign initial conditions
    ##set hat function I.C. : u(.5<=x<=1 && .5<=y<=1 ) is 2
    u[int(.5 / dy):int(1 / dy + 1), int(.5 / dx):int(1 / dx + 1)] = 2
    ##set hat function I.C. : v(.5<=x<=1 && .5<=y<=1 ) is 2
    v[int(.5 / dy):int(1 / dy + 1), int(.5 / dx):int(1 / dx + 1)] = 2
    row, col = u.shape
    kx=dt/dx
    ky=dt/dy
    
    for k in range(nt):
        un=u.copy()
        vn=v.copy()
        for i in range(1, row-1):
            for j in range(1, col-1):
                                                          
                u[i,j]=(un[i,j] -
                        kx*un[i,j]*(un[i,j] - un[i-1,j]) -
                        ky*vn[i,j]*(un[i,j] - un[i,j-1]))
                
                u[i,j]=(vn[i,j] -
                        kx*un[i,j]*(vn[i,j] - vn[i-1,j]) -
                        ky*vn[i,j]*(vn[i,j] - vn[i,j-1]))
                
                                
        u[0, :] = 1
        u[:, 0] = 1
        u[row-1, :] = 1
        u[:, col-1] = 1
        
        v[0, :] = 1
        v[:, 0] = 1
        v[row-1, :] = 1
        v[:, col-1] = 1
        
    return 0

# %% [markdown]
# ## Pyccel accelerator

# %%
@types('float[:,:]', 'float[:,:]','float[:,:]','float[:,:]' , 'int','float', 'float','float', 'float')
def solve_2d_nonlinearconv_pyccel(u, un, v, vn, nt, dt, dx, dy, c):

    ###Assign initial conditions
    ##set hat function I.C. : u(.5<=x<=1 && .5<=y<=1 ) is 2
    u[int(.5 / dy):int(1 / dy + 1), int(.5 / dx):int(1 / dx + 1)] = 2
    ##set hat function I.C. : v(.5<=x<=1 && .5<=y<=1 ) is 2
    v[int(.5 / dy):int(1 / dy + 1), int(.5 / dx):int(1 / dx + 1)] = 2
    row, col = u.shape
    
    kx=dt/dx
    ky=dt/dy
    
    for k in range(nt):
        un=u.copy()
        vn=v.copy()
        for i in range(1, row-1):
            for j in range(1, col-1):
                                                          
                u[i,j]=(un[i,j] -
                        kx*un[i,j]*(un[i,j] - un[i-1,j]) -
                        ky*vn[i,j]*(un[i,j] - un[i,j-1]))
                
                u[i,j]=(vn[i,j] -
                        kx*un[i,j]*(vn[i,j] - vn[i-1,j]) -
                        ky*vn[i,j]*(vn[i,j] - vn[i,j-1]))
                
                                
        u[0, :] = 1
        u[:, 0] = 1
        u[row-1, :] = 1
        u[:, col-1] = 1
        
        v[0, :] = 1
        v[:, 0] = 1
        v[row-1, :] = 1
        v[:, col-1] = 1
        
        
    return 0

# %% [markdown]
# ## Inputs

# %%
###variable declarations
nx = 101
ny = 101
nt = 800
c = 1
dx = 2 / (nx - 1)
dy = 2 / (ny - 1)
sigma = .2
dt = sigma * dx

x = np.linspace(0, 2, nx)
y = np.linspace(0, 2, ny)

u = np.ones((ny, nx)) ##create a 1xn vector of 1's
v = np.ones((ny, nx))
un = np.ones((ny, nx))
vn = np.ones((ny, nx))     

solve_2d_nonlinearconv_pure(u, un, v, vn, nt, dt, dx, dy, c)

fig = pyplot.figure(figsize=(7, 5), dpi=100)
ax = fig.gca(projection='3d')                      
X, Y = np.meshgrid(x, y)                            
surf = ax.plot_surface(X, Y, u, cmap=cm.viridis)


fig = pyplot.figure(figsize=(7, 5), dpi=100)
ax = fig.gca(projection='3d')
surf2 = ax.plot_surface(X, Y, v, cmap=cm.viridis)

# %% [markdown]
# ## Call Funtions

# %% [markdown]
# ### Pure function

# %%
# %timeit solve_2d_nonlinearconv_pure(u, un, v, vn, nt, dt, dx, dy, c)
# Out:
# 33.5 s ± 768 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### Function with numba accelerator

# %%
# %timeit solve_2d_nonlinearconv_numba(u, un, v, vn, nt, dt, dx, dy, c)
# Out:
# 12 ms ± 245 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### Function with pyccel accelerator

# %%
solve_2d_nonlinearconv_f90 = epyccel(solve_2d_nonlinearconv_pyccel)
# Out:
# ERROR at annotation (semantic) stage
# pyccel:
#  |fatal [semantic]: mod_i4ipbm8c.py [15,8]| Attribute copy not found
# ---------------------------------------------------------------------------
# PyccelSemanticError                       Traceback (most recent call last)
# <ipython-input-9-6f2b99195407> in <module>
# ----> 1 solve_2d_nonlinearconv_f90 = epyccel(solve_2d_nonlinearconv_pyccel)
#
# ~/anaconda3/lib/python3.7/site-packages/pyccel/epyccel.py in epyccel(python_function_or_module, **kwargs)
#     275     # Serial version
#     276     else:
# --> 277         mod, fun = epyccel_seq( python_function_or_module, **kwargs )
#     278
#     279     # Return Fortran function (if any), otherwise module
#
# ~/anaconda3/lib/python3.7/site-packages/pyccel/epyccel.py in epyccel_seq(function_or_module, language, compiler, mpi_compiler, fflags, accelerator, verbose, debug, includes, libdirs, modules, libs, extra_args, folder)
#     131                        extra_args  = extra_args,
#     132                        accelerator = accelerator,
# --> 133                        output_name = module_name)
#     134     finally:
#     135         # Change working directory back to starting point
#
# ~/anaconda3/lib/python3.7/site-packages/pyccel/codegen/pipeline.py in execute_pyccel(fname, syntax_only, semantic_only, convert_only, recursive, verbose, folder, language, compiler, mpi_compiler, fflags, includes, libdirs, modules, libs, debug, extra_args, accelerator, output_name)
#     158         handle_error('annotation (semantic)')
#     159         # Raise a new error to avoid a large traceback
# --> 160         raise PyccelSemanticError('Semantic step failed') from None
#     161
#     162     if errors.has_errors():
#
# PyccelSemanticError: Semantic step failed

# %%
# %timeit solve_2d_nonlinearconv_f90(u, un, v, vn, nt, dt, dx, dy, c)
